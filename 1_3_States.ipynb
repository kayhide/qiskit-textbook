# %%
from qiskit import QuantumCircuit, assemble, Aer
from qiskit.visualization import plot_histogram, plot_bloch_vector
from math import sqrt, pi

# %%
qc = QuantumCircuit(1)
initial_state = [0, 1]
qc.initialize(initial_state, 0)
qc.save_statevector()
qc.draw()

# %%
sim = Aer.get_backend('aer_simulator')
qobj = assemble(qc)
result = sim.run(qobj).result()
out_state = result.get_statevector()
print(out_state)
# Out:
# [0.+0.j 1.+0.j]

# %%
qc.measure_all()
qc.draw()

# %%
qobj = assemble(qc)
result = sim.run(qobj).result()
counts = result.get_counts()
plot_histogram(counts)

# %%
qc = QuantumCircuit(1)
initial_state = [1/sqrt(2), 1j/sqrt(2)]
qc.initialize(initial_state, 0)
qc.save_statevector()
qobj = assemble(qc)
state = sim.run(qobj).result().get_statevector()
print(state)
# Out:
# [0.70710678+0.j         0.        +0.70710678j]

# %%
qobj = assemble(qc)
results = sim.run(qobj).result().get_counts()
plot_histogram(results)

# %%
qc = QuantumCircuit(2)
# qc.initialize([1/sqrt(3), sqrt(2)/sqrt(3)], 0)
qc.initialize([1/sqrt(3), 1.j * sqrt(2)/sqrt(3)], 1)
qc.save_statevector()
qobj = assemble(qc)
state = sim.run(qobj).result().get_statevector()
print(state)
# Out:
# [0.57735027+0.j         0.        +0.j         0.        +0.81649658j
#  0.        +0.j        ]

# %%
results = sim.run(qobj).result().get_counts()
plot_histogram(results)

# %%
def plot_bloch_vector_spherical(theta, phi):
    return plot_bloch_vector([1, theta, phi], coord_type="spherical")

# %%
plot_bloch_vector_spherical(0, 0)
# Out:
# /home/kayhide/wrk/qiskit/textbook/.direnv/python-3.8.9/lib/python3.8/site-packages/qiskit/visualization/bloch.py:402: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
# /home/kayhide/wrk/qiskit/textbook/.direnv/python-3.8.9/lib/python3.8/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %%
plot_bloch_vector_spherical(pi, 0)
# Out:
# /home/kayhide/wrk/qiskit/textbook/.direnv/python-3.8.9/lib/python3.8/site-packages/qiskit/visualization/bloch.py:402: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
# /home/kayhide/wrk/qiskit/textbook/.direnv/python-3.8.9/lib/python3.8/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %%
plot_bloch_vector_spherical(pi/2, 0)
# Out:
# /home/kayhide/wrk/qiskit/textbook/.direnv/python-3.8.9/lib/python3.8/site-packages/qiskit/visualization/bloch.py:402: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
# /home/kayhide/wrk/qiskit/textbook/.direnv/python-3.8.9/lib/python3.8/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %%
plot_bloch_vector_spherical(pi/2, -pi/2)
# Out:
# /home/kayhide/wrk/qiskit/textbook/.direnv/python-3.8.9/lib/python3.8/site-packages/qiskit/visualization/bloch.py:402: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
# /home/kayhide/wrk/qiskit/textbook/.direnv/python-3.8.9/lib/python3.8/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
